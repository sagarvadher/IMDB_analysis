# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv('/Users/sagar/Desktop/imdbb.csv')

# %%
df.head()
# Out:
#    color      director_name  num_critic_for_reviews  duration  \
# 0  Color      James Cameron                   723.0     178.0
# 1  Color     Gore Verbinski                   302.0     169.0
# 2  Color         Sam Mendes                   602.0     148.0
# 3  Color  Christopher Nolan                   813.0     164.0
# 4    NaN        Doug Walker                     NaN       NaN
#
#    director_facebook_likes  actor_3_facebook_likes      actor_2_name  \
# 0                      0.0                   855.0  Joel David Moore
# 1                    563.0                  1000.0     Orlando Bloom
# 2                      0.0                   161.0      Rory Kinnear
# 3                  22000.0                 23000.0    Christian Bale
# 4                    131.0                     NaN        Rob Walker
#
#    actor_1_facebook_likes        gross                           genres  \
# 0                  1000.0  760505847.0  Action|Adventure|Fantasy|Sci-Fi
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5043 entries, 0 to 5042
# Data columns (total 28 columns):
# color                        5024 non-null object
# director_name                4939 non-null object
# num_critic_for_reviews       4993 non-null float64
# duration                     5028 non-null float64
# director_facebook_likes      4939 non-null float64
# actor_3_facebook_likes       5020 non-null float64
# actor_2_name                 5030 non-null object
# actor_1_facebook_likes       5036 non-null float64
# gross                        4159 non-null float64
# genres                       5043 non-null object
# actor_1_name                 5036 non-null object
# movie_title                  5043 non-null object
# num_voted_users              5043 non-null int64
# cast_total_facebook_likes    5043 non-null int64
# actor_3_name                 5020 non-null object
# facenumber_in_poster         5030 non-null float64
# ...

# %%
df.describe()
# Out:
#        num_critic_for_reviews     duration  director_facebook_likes  \
# count             4993.000000  5028.000000              4939.000000
# mean               140.194272   107.201074               686.509212
# std                121.601675    25.197441              2813.328607
# min                  1.000000     7.000000                 0.000000
# 25%                 50.000000    93.000000                 7.000000
# 50%                110.000000   103.000000                49.000000
# 75%                195.000000   118.000000               194.500000
# max                813.000000   511.000000             23000.000000
#
#        actor_3_facebook_likes  actor_1_facebook_likes         gross  \
# count             5020.000000             5036.000000  4.159000e+03
# mean               645.009761             6560.047061  4.846841e+07
# std               1665.041728            15020.759120  6.845299e+07
# min                  0.000000                0.000000  1.620000e+02
# ...

# %%
df1 = df.drop(['duration', 'aspect_ratio'], axis=1)

# %%
list(df1.columns.values)
# Out:
# ['color',
#  'director_name',
#  'num_critic_for_reviews',
#  'director_facebook_likes',
#  'actor_3_facebook_likes',
#  'actor_2_name',
#  'actor_1_facebook_likes',
#  'gross',
#  'genres',
#  'actor_1_name',
#  'movie_title',
#  'num_voted_users',
#  'cast_total_facebook_likes',
#  'actor_3_name',
#  'facenumber_in_poster',
#  'plot_keywords',
#  'movie_imdb_link',
#  'num_user_for_reviews',
#  'language',
#  'country',
#  'content_rating',
#  'budget',
#  'title_year',
#  'actor_2_facebook_likes',
#  'imdb_score',
#  'movie_facebook_likes']

# %%
df1.sort_values(by='movie_facebook_likes', ascending=False)
# Out:
#                  color          director_name  num_critic_for_reviews  \
# 96               Color      Christopher Nolan                   712.0
# 296              Color      Quentin Tarantino                   765.0
# 10               Color            Zack Snyder                   673.0
# 128              Color          George Miller                   739.0
# 179              Color  Alejandro G. Iñárritu                   556.0
# 97               Color      Christopher Nolan                   642.0
# 99               Color          Peter Jackson                   645.0
# 2614             Color          Morten Tyldum                   454.0
# 3                Color      Christopher Nolan                   813.0
# 278              Color           Ridley Scott                   568.0
# 29               Color        Colin Trevorrow                   644.0
# 1578             Color           Wes Anderson                   536.0
# ...

# %%
list(df1.columns.values)
# Out:
# ['color',
#  'director_name',
#  'num_critic_for_reviews',
#  'director_facebook_likes',
#  'actor_3_facebook_likes',
#  'actor_2_name',
#  'actor_1_facebook_likes',
#  'gross',
#  'genres',
#  'actor_1_name',
#  'movie_title',
#  'num_voted_users',
#  'cast_total_facebook_likes',
#  'actor_3_name',
#  'facenumber_in_poster',
#  'plot_keywords',
#  'movie_imdb_link',
#  'num_user_for_reviews',
#  'language',
#  'country',
#  'content_rating',
#  'budget',
#  'title_year',
#  'actor_2_facebook_likes',
#  'imdb_score',
#  'movie_facebook_likes']

# %%
df1['content_rating'].value_counts()
# Out:
# R            2118
# PG-13        1461
# PG            701
# Not Rated     116
# G             112
# Unrated        62
# Approved       55
# TV-14          30
# TV-MA          20
# TV-PG          13
# X              13
# TV-G           10
# Passed          9
# NC-17           7
# GP              6
# M               5
# TV-Y7           1
# TV-Y            1
# Name: content_rating, dtype: int64

# %%
df1['actor_1_name'].value_counts()
# Out:
# Robert De Niro            49
# Johnny Depp               41
# Nicolas Cage              33
# J.K. Simmons              31
# Denzel Washington         30
# Matt Damon                30
# Bruce Willis              30
# Liam Neeson               29
# Steve Buscemi             27
# Robin Williams            27
# Harrison Ford             27
# Jason Statham             26
# Bill Murray               26
# Robert Downey Jr.         26
# Morgan Freeman            25
# Tom Cruise                25
# Tom Hanks                 24
# Keanu Reeves              24
# Christian Bale            23
# Kevin Spacey              22
# Scarlett Johansson        22
# Gerard Butler             22
# Hugh Jackman              21
# Leonardo DiCaprio         21
# Anthony Hopkins           21
# Sylvester Stallone        21
# Philip Seymour Hoffman    20
# Will Ferrell              20
# Matthew McConaughey       20
# Dwayne Johnson            19
#                           ..
# Sunny Mabrey               1
# ...

# %%
df1[(df1.actor_1_name == 'Robert De Niro') & (df1.director_name=='Martin Scorsese')].shape[0]
# Out:
# 7

# %%
df1['director_name'].value_counts()
# Out:
# Steven Spielberg         26
# Woody Allen              22
# Clint Eastwood           20
# Martin Scorsese          20
# Ridley Scott             17
# Spike Lee                16
# Steven Soderbergh        16
# Tim Burton               16
# Renny Harlin             15
# Oliver Stone             14
# John Carpenter           13
# Joel Schumacher          13
# Sam Raimi                13
# Robert Zemeckis          13
# Ron Howard               13
# Michael Bay              13
# Barry Levinson           13
# Robert Rodriguez         13
# Kevin Smith              12
# Shawn Levy               12
# Tony Scott               12
# Peter Jackson            12
# Wes Craven               12
# Brian De Palma           12
# Richard Donner           12
# Rob Reiner               11
# Francis Ford Coppola     11
# Stephen Frears           11
# Richard Linklater        11
# Rob Cohen                11
#                          ..
# Bryan Barber              1
# Timothy Björklund         1
# ...

# %%
df_rdn = df1[df1.actor_1_name == 'Robert De Niro']

# %%
df_rdn['genres'].value_counts()
# Out:
# Comedy|Romance                               4
# Crime|Drama|Thriller                         4
# Crime|Drama                                  3
# Comedy|Drama                                 3
# Comedy|Crime                                 3
# Action|Crime|Thriller                        3
# Biography|Crime|Drama                        2
# Drama|Horror|Mystery|Thriller                2
# Crime|Thriller                               2
# Comedy                                       2
# Crime|Drama|Romance|Thriller                 1
# Action|Crime|Drama|Mystery|Thriller          1
# Action|Comedy|Crime|Thriller                 1
# Drama|Music|Musical|Romance                  1
# Biography|Drama|Sport                        1
# Drama|Sci-Fi                                 1
# Action|Adventure|Crime|Thriller              1
# Drama|War                                    1
# Action|Biography|Drama|Sport                 1
# Drama|Romance                                1
# ...

# %%
df_rdn_gn  = df_rdn['genres'].str.split('|',expand=True)

# %%
df_rdn_gn
# Out:
#               0          1         2         3         4
# 293      Comedy    Romance      None      None      None
# 518   Adventure  Animation    Comedy    Family   Fantasy
# 541   Adventure  Animation    Comedy    Family      None
# 632       Crime      Drama  Thriller      None      None
# 710      Comedy    Romance      None      None      None
# 783      Comedy      Crime      None      None      None
# 784      Action      Crime     Drama   Mystery  Thriller
# 838      Comedy       None      None      None      None
# 868      Action  Adventure     Crime  Thriller      None
# 879      Action      Drama     Sport  Thriller      None
# 920   Biography      Crime     Drama      None      None
# 1140      Crime      Drama  Thriller      None      None
# 1168     Action      Crime     Drama  Thriller      None
# 1209     Comedy      Drama      None      None      None
# 1281      Crime      Drama   Romance  Thriller      None
# ...

# %%
df_rdn_gn= df_rdn_gn['0'] + df_rdn_gn['1']
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# pandas/index.pyx in pandas.index.IndexEngine.get_loc (pandas/index.c:4279)()
#
# pandas/src/hashtable_class_helper.pxi in pandas.hashtable.Int64HashTable.get_item (pandas/hashtable.c:8543)()
#
# TypeError: an integer is required
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# /Users/sagar/anaconda/lib/python3.6/site-packages/pandas/indexes/base.py in get_loc(self, key, method, tolerance)
#    2133             try:
# -> 2134                 return self._engine.get_loc(key)
#    2135             except KeyError:
#
# pandas/index.pyx in pandas.index.IndexEngine.get_loc (pandas/index.c:4433)()
#
# pandas/index.pyx in pandas.index.IndexEngine.get_loc (pandas/index.c:4363)()
#
# KeyError: '0'
#
# ...

# %%
len(df_rdn_gn)
# Out:
# 49

# %%
df_rdn_gn_z = df_rdn_gn.loc[:,:'0']
df_rdn_gn_o = df_rdn_gn.loc[:,:'1']
df_rdn_gn_tw = df_rdn_gn.loc[:,:'2']
df_rdn_gn_th = df_rdn_gn.loc[:,:'3']

# %%
df_rdn_gn_z
# Out:
#               0
# 293      Comedy
# 518   Adventure
# 541   Adventure
# 632       Crime
# 710      Comedy
# 783      Comedy
# 784      Action
# 838      Comedy
# 868      Action
# 879      Action
# 920   Biography
# 1140      Crime
# 1168     Action
# 1209     Comedy
# 1281      Crime
# 1285      Crime
# 1337     Comedy
# 1411      Crime
# 1463     Action
# 1548  Biography
# 1605     Comedy
# 1655     Action
# 1704      Drama
# 1714      Crime
# 1764     Comedy
# 1827     Comedy
# 1829     Comedy
# 1854     Comedy
# 1884      Crime
# 1901      Drama
# 1903  Biography
# 2045      Drama
# 2124      Drama
# 2290     Comedy
# 2294  Adventure
# 2351     Action
# 2425  Biography
# 2474      Drama
# 2629      Drama
# 2630     Comedy
# 2636      Crime
# 2700      Drama
# 2794      Drama
# 2837      Crime
# 2911     Action
# 2930      Crime
# 3025     Comedy
# 3317     Action
# 4535      Crime

# %%
df_rdn_gn = pd.concat([df_rdn_gn_o, df_rdn_gn_tw,df_rdn_gn_th, df_rdn_gn_z], ignore_index=True)

# %%
list(df_rdn_gn.columns.values)
#df1 = df.drop(['duration', 'aspect_ratio'], axis=1)
# Out:
# [0, 1, 2, 3]

# %%
#df_rdn_gn.drop(columns = ['1'])
#df.drop(columns=['B', 'C'])
df_rdn_gn_now = df_rdn_gn.loc[:,:'0']

# %%
df_rdn_gn_now.dropna()
# Out:
#              0
# 0       Comedy
# 1    Adventure
# 2    Adventure
# 3        Crime
# 4       Comedy
# 5       Comedy
# 6       Action
# 7       Comedy
# 8       Action
# 9       Action
# 10   Biography
# 11       Crime
# 12      Action
# 13      Comedy
# 14       Crime
# 15       Crime
# 16      Comedy
# 17       Crime
# 18      Action
# 19   Biography
# 20      Comedy
# 21      Action
# 22       Drama
# 23       Crime
# 24      Comedy
# 25      Comedy
# 26      Comedy
# 27      Comedy
# 28       Crime
# 29       Drama
# ..         ...
# 166  Biography
# 167     Comedy
# 168     Action
# 169      Drama
# 170      Crime
# 171     Comedy
# 172     Comedy
# 173     Comedy
# 174     Comedy
# 175      Crime
# 176      Drama
# 177  Biography
# 178      Drama
# 179      Drama
# 180     Comedy
# 181  Adventure
# 182     Action
# 183  Biography
# 184      Drama
# 185      Drama
# 186     Comedy
# 187      Crime
# 188      Drama
# 189      Drama
# 190      Crime
# 191     Action
# ...

# %%
df_rdn_gn_now.describe()
# Out:
#              0
# count      196
# unique       6
# top     Comedy
# freq        56

# %%
import matplotlib.pyplot as plt

# %%
df_rdn_gn_now.groupby
# Out:
# <bound method NDFrame.groupby of              0
# 0       Comedy
# 1    Adventure
# 2    Adventure
# 3        Crime
# 4       Comedy
# 5       Comedy
# 6       Action
# 7       Comedy
# 8       Action
# 9       Action
# 10   Biography
# 11       Crime
# 12      Action
# 13      Comedy
# 14       Crime
# 15       Crime
# 16      Comedy
# 17       Crime
# 18      Action
# 19   Biography
# 20      Comedy
# 21      Action
# 22       Drama
# 23       Crime
# 24      Comedy
# 25      Comedy
# 26      Comedy
# 27      Comedy
# 28       Crime
# 29       Drama
# ..         ...
# 166  Biography
# 167     Comedy
# 168     Action
# 169      Drama
# 170      Crime
# 171     Comedy
# 172     Comedy
# 173     Comedy
# 174     Comedy
# 175      Crime
# 176      Drama
# 177  Biography
# 178      Drama
# 179      Drama
# 180     Comedy
# 181  Adventure
# 182     Action
# 183  Biography
# 184      Drama
# 185      Drama
# 186     Comedy
# 187      Crime
# 188      Drama
# 189      Drama
# ...

# %%
import os
cwd = os.getcwd()
print(cwd)
# Out:
# /Users/sagar
